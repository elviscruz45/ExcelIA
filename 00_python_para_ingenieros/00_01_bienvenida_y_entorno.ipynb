# %% [markdown]
# # Lección 00_01 — Bienvenida y entorno Python

# %% [markdown]
# ## 1. Objetivo
#
# Entender qué es Python, cómo se usa en mantenimiento predictivo de plantas concentradoras y ejecutar tu primera línea de código en Jupyter.

# %% [markdown]
# ## 2. Concepto
#
# **Python** es un lenguaje de programación legible que usan ingenieros para analizar datos de sensores, calcular indicadores (MTBF, disponibilidad) y automatizar reportes.
#
# En una planta concentradora, Python puede procesar miles de lecturas de bombas, molinos y celdas de flotación más rápido que hacerlo manualmente en Excel.

# %% [markdown]
# ### Desde cero
#
# > **¿Nunca usaste Colab?** Lee primero [`GUIA_00_antes_de_empezar.md`](GUIA_00_antes_de_empezar.md) con tu instructor (~30 min). Ahí explicamos internet, navegador, subir el notebook y ejecutar la primera celda.
#
# Un **programa** es una lista de instrucciones. En Jupyter, cada **celda de código** es una instrucción que ejecutas con **Shift + Enter**.
#
# **Si vienes de Excel:** una celda de código es como una celda con fórmula; `print()` es como ver el resultado en pantalla. El mapa completo del curso está en [`GUIA_MAPA_CURSO_MINERIA50.md`](../GUIA_MAPA_CURSO_MINERIA50.md).

# %% [markdown]
# ## 3. Ejemplos guiados

# %%
import os
from pathlib import Path

MOD_DIR = Path.cwd()
os.chdir(MOD_DIR)
OUTPUT_DIR = MOD_DIR / "outputs"
OUTPUT_DIR.mkdir(exist_ok=True)
DATA_DIR = MOD_DIR / "data"

# %%
print("Monitoreo PUMP101 activo — turno día iniciado")
# Out:
# Monitoreo PUMP101 activo — turno día iniciado

# %%
# Mostrar información del entorno de trabajo
print("Directorio de trabajo:", MOD_DIR)
print("Carpeta de datos:", DATA_DIR)
print("Carpeta de salidas:", OUTPUT_DIR)
# Out:
# Directorio de trabajo: /Users/elviscruz45/Desktop/ExcelA/00_python_para_ingenieros
# Carpeta de datos: /Users/elviscruz45/Desktop/ExcelA/00_python_para_ingenieros/data
# Carpeta de salidas: /Users/elviscruz45/Desktop/ExcelA/00_python_para_ingenieros/outputs

# %% [markdown]
# ## 4. Errores comunes
#
# - **Olvidar ejecutar la celda:** El código no corre solo; presiona Shift + Enter.
# - **SyntaxError:** Revisa comillas, paréntesis y dos puntos (`:`).
# - **NameError:** Ejecutaste celdas fuera de orden; vuelve arriba y ejecuta desde el inicio.

# %% [markdown]
# ## 5. Ejercicio práctico — Tu primer reporte de turno
#
# Imprime un mensaje que indique el equipo, el turno y el estado operativo. Ejemplo: `PUMP101 | Turno Día | Estado: En servicio`

# %%
equipo = "PUMP101"
turno = "Día"
estado = "En servicio"
print(f"{equipo} | Turno {turno} | Estado: {estado}")
# Out:
# PUMP101 | Turno Día | Estado: En servicio

# %% [markdown]
# ## 6. Resumen y siguiente paso
#
# - Python se ejecuta celda a celda en Jupyter.
# - `print()` muestra texto en pantalla.
# - El entorno ExcelA ya tiene las librerías que usarás después.
#
# **Siguiente lección:** `00_02_variables_y_unidades.ipynb`
